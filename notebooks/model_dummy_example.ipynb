# %%
import torch, torch.nn as nn

class HeteroDemo(nn.Module):
    """
    One Conv, one Encoder-Attn, one LSTM, one Dense.
    Bx1x60x90 → Bx10
    """
    def __init__(self):
        super().__init__()
        self.conv = nn.Conv2d(1, 8, kernel_size=3, padding=1)          # CPU
        self.patch = nn.Unfold(kernel_size=(4,4), stride=(4,4))        # 15×22 patches
        self.attn = nn.TransformerEncoderLayer(d_model=128,
                                               nhead=4, batch_first=True) # GPU
        self.lstm = nn.LSTM(input_size=8*60*90 + 128, hidden_size=64,
                            num_layers=1, batch_first=True)            # CPU
        self.fc   = nn.Linear(64, 10)                                  # CPU

    def forward(self, x, h0=None):
        b = x.size(0)

        # 1) convolution branch
        a = self.conv(x).flatten(1)        # (B, 8*60*90)

        # 2) ViT-like branch
        p = self.patch(x)                  # (B, 8*4*4, 15*22)
        p = p.transpose(1,2)               # (B, 330, 128)
        print(p.shape)
        p = self.attn(p)[:,0]              # CLS token (B,128)

        # 3) fusion → LSTM
        fused = torch.cat([a, p], dim=-1).unsqueeze(1)  # time-len = 1
        y, h = self.lstm(fused, h0)        # keep state external

        # 4) classifier
        return self.fc(y.squeeze(1)), h

# %%
model = HeteroDemo().eval()
example = (torch.randn(1,1,60,90),)      # compile-time shape
output_example = model(*example)               # run-time shape
print("Output shape:", output_example[0].shape)  # (1,10)
print("Hidden shape:", output_example[1][0].shape)  # (1,1,64)
# Out:
# torch.Size([1, 330, 16])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 model = HeteroDemo().eval()
#       2 example = (torch.randn(1,1,60,90),)      # compile-time shape
# ----> 3 output_example = model(*example)               # run-time shape
#       4 print("Output shape:", output_example[0].shape)  # (1,10)
#       5 print("Hidden shape:", output_example[1][0].shape)  # (1,1,64)
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[6], line 28, in HeteroDemo.forward(self, x, h0)
#      26 p = p.transpose(1,2)               # (B, 330, 128)
#      27 print(p.shape)
# ---> 28 p = self.attn(p)[:,0]              # CLS token (B,128)
#      30 # 3) fusion → LSTM
#      31 fused = torch.cat([a, p], dim=-1).unsqueeze(1)  # time-len = 1
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/transformer.py:920, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     916     x = x + self._ff_block(self.norm2(x))
#     917 else:
#     918     x = self.norm1(
#     919         x
# --> 920         + self._sa_block(x, src_mask, src_key_padding_mask, is_causal=is_causal)
#     921     )
#     922     x = self.norm2(x + self._ff_block(x))
#     924 return x
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/transformer.py:934, in TransformerEncoderLayer._sa_block(self, x, attn_mask, key_padding_mask, is_causal)
#     927 def _sa_block(
#     928     self,
#     929     x: Tensor,
#    (...)
#     932     is_causal: bool = False,
#     933 ) -> Tensor:
# --> 934     x = self.self_attn(
#     935         x,
#     936         x,
#     937         x,
#     938         attn_mask=attn_mask,
#     939         key_padding_mask=key_padding_mask,
#     940         need_weights=False,
#     941         is_causal=is_causal,
#     942     )[0]
#     943     return self.dropout1(x)
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/modules/activation.py:1373, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1347     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1348         query,
#    1349         key,
#    (...)
#    1370         is_causal=is_causal,
#    1371     )
#    1372 else:
# -> 1373     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1374         query,
#    1375         key,
#    1376         value,
#    1377         self.embed_dim,
#    1378         self.num_heads,
#    1379         self.in_proj_weight,
#    1380         self.in_proj_bias,
#    1381         self.bias_k,
#    1382         self.bias_v,
#    1383         self.add_zero_attn,
#    1384         self.dropout,
#    1385         self.out_proj.weight,
#    1386         self.out_proj.bias,
#    1387         training=self.training,
#    1388         key_padding_mask=key_padding_mask,
#    1389         need_weights=need_weights,
#    1390         attn_mask=attn_mask,
#    1391         average_attn_weights=average_attn_weights,
#    1392         is_causal=is_causal,
#    1393     )
#    1394 if self.batch_first and is_batched:
#    1395     return attn_output.transpose(1, 0), attn_output_weights
#
# File ~/miniconda3/envs/mobileSAM/lib/python3.9/site-packages/torch/nn/functional.py:6202, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    6196     if key_padding_mask is not None:
#    6197         # We have the attn_mask, and use that to merge kpm into it.
#    6198         # Turn off use of is_causal hint, as the merged mask is no
#    6199         # longer causal.
#    6200         is_causal = False
# -> 6202 assert (
#    6203     embed_dim == embed_dim_to_check
#    6204 ), f"was expecting embedding dimension of {embed_dim_to_check}, but got {embed_dim}"
#    6205 if isinstance(embed_dim, torch.Tensor):
#    6206     # embed_dim can be a tensor when JIT tracing
#    6207     head_dim = embed_dim.div(num_heads, rounding_mode="trunc")
#
# AssertionError: was expecting embedding dimension of 128, but got 16
